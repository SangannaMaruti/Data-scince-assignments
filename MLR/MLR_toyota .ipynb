# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from statsmodels.graphics.regressionplots import influence_plot
import numpy as np

# %%
#load dataset
Toyota=pd.read_csv("Toyota Corolla.txt",encoding='ANSI')
Toyota
# Out:
#                                                                                                              Consider only the below columns and prepare a prediction model for predicting Price.
# Corolla<-Corolla[c("Price"                         Age_08_04 KM    HP      cc     Doors  Gears Quarterly_Tax                                           Weight)]
# Model -- model of the car                          NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Price  -- Offer Price in EUROs\t                   NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Age_08_04 -- Age in months as in August 2004\t     NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Mfg_Month -- Manufacturing month (1-12)\t          NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Mfg_Year\t-- Manufacturing Year                    NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# KM -- Accumulated Kilometers on odometer           NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Fuel_Type\t -- Fuel Type (Petrol                    Diesel    CNG) NaN     NaN    NaN    NaN   NaN                                                          NaN
# HP -- Horse Power                                  NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Met_Color\t -- Metallic Color?  (Yes=1              No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Color -- Color (Blue                                Red       Grey  Silver  Black  etc.) NaN   NaN                                                          NaN
# Automatic\t-- Automatic ( (Yes=1                    No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# cc -- Cylinder Volume in cubic centimeters         NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Doors -- Number of doors                           NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Cylinders\t-- Number of cylinders                  NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Gears -- Number of gear positions                  NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Quarterly_Tax -- Quarterly road tax in EUROs       NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Weight -- Weight in Kilograms                      NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Mfr_Guarantee -- Within Manufacturer's Guarante...  No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# BOVAG_Guarantee -- BOVAG (Dutch dealer network)...  No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Guarantee_Period -- \tGuarantee period in months   NaN       NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# ABS -- Anti-Lock Brake System (Yes=1                No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Airbag_1 -- Driver_Airbag  (Yes=1                   No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Airbag_2 -- Passenger Airbag  (Yes=1                No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Airco -- Airconditioning  (Yes=1                    No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Automatic_airco -- Automatic Airconditioning  (...  No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Boardcomputer -- Boardcomputer  (Yes=1              No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# CD_Player -- CD Player  (Yes=1                      No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Central_Lock -- Central Lock  (Yes=1                No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Powered_Windows -- Powered Windows  (Yes=1          No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Power_Steering -- Power Steering  (Yes=1            No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Radio -- Radio  (Yes=1                              No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Mistlamps\t-- Mistlamps  (Yes=1                     No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Sport_Model -- Sport Model  (Yes=1                  No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Backseat_Divider -- Backseat Divider  (Yes=1        No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Metallic_Rim --Metallic Rim  (Yes=1                 No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Radio_cassette -- Radio Cassette  (Yes=1            No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN
# Tow_Bar -- Tow Bar  (Yes=1                          No=0)    NaN   NaN     NaN    NaN    NaN   NaN                                                          NaN

# %%
Toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 38 entries, ('Corolla<-Corolla[c("Price"', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'Quarterly_Tax') to ('Tow_Bar -- Tow Bar  (Yes=1', ' No=0)', nan, nan, nan, nan, nan, nan)
# Data columns (total 1 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   Consider only the below columns and prepare a prediction model for predicting Price.  1 non-null      object
# dtypes: object(1)
# memory usage: 3.0+ KB
